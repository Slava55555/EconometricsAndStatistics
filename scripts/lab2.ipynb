# %%
# библиотеки
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter
import scipy.stats as sts

# %%
# %store -r data
data['duration'] = (data['end_date'] - data['start_date']).dt.days

# %%
# Построение ящика с усами для оценок по типам
sns.boxplot(x='type', y='score', data=data)

plt.title("Распределение оценок по типам")
plt.xlabel("тип")
plt.ylabel("оценка")

plt.show()

# %%
sns.boxplot(x='status', y='duration', data=data,  showfliers=True)
plt.show()

# %%
# %store -r top_themes
theme_explode = data.explode("themes").reset_index(drop=True)
theme_final = theme_explode[theme_explode["themes"].isin(top_themes["Theme"])]

# %%
sns.boxplot(x='themes', y='score', data=theme_final)
plt.show()

# %%
sns.boxplot(x='themes', y='chapters', data=theme_final)
plt.show()

# %%
# %store -r top_genres
genre_explode = data.explode("genres").reset_index(drop=True)
genre_final = genre_explode[genre_explode["genres"].isin(top_genres["Genre"])]

# %%
sns.boxplot(x='genres', y='score', data=genre_final)
plt.show()

# %%
sns.boxplot(x='genres', y='volumes', data=genre_final)
plt.show()
